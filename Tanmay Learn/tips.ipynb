# %% [markdown]
# 1) #Way to make transpose :- zip(*grid)
#
# Counter(tuple(grid)):
#  {(1,2,1,9): 2, (2,8,9,2): 1, (9,2,6,3): 1}
#
# Counter(zip(*grid)):
#  {(1,2,1,9): 1, (2,8,2,2): 1, (1,9,1,6): 1, (9,2,9,3): 1}
